# %%
print("hello world ")

# %%
import numpy as np

# %%
from math import *
print(sqrt(25))
# Out:
# 5.0

# %%
from package.multipys import multiply
result = multiply(5, 10)
print(result)
# Out:
# 50

# %%
from package.maths import *
result = addition(5, 10)
x = division(4,2)

print(result)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from package.maths import *
#       2 result = addition(5, 10)
# ----> 3 x = division(4,2)
#       5 print(result)
#       6 print(x)
#
# NameError: name 'division' is not defined

# %%
from package.maths import addition
y = addition(20, 4)
print(y)
# Out:
# 24

# %%
from package.maths import division
y = division(20, 4)
print(y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from package.maths import division
#       2 y = division(20, 4)
#       3 print(y)
#
# ImportError: cannot import name 'division' from 'package.maths' (/Users/cpasunuti/Desktop/my mac/Coding/Python/myGit/chaithanyapythontest/package/maths.py)

# %%
from package.maths import *
y = div2(30, 5)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 from package.maths import *
# ----> 2 y = div2(30, 5)
#       3 print(y)
#
# NameError: name 'div2' is not defined
