# %%
[x**2 for x in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
packed_tuple = (1, 2, "hello", 4, 5)
a,b,c,d,e = packed_tuple
print(a)
print(b)
print(type(c))
# Out:
# 1
# 2
# <class 'str'>

# %%
numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
        if number in frequency:
            frequency[number] += 1
        else:
            frequency[number] = 1   
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# ⚙️ Summary Table
# Symbol	        Collects	              Stored As.      	Used For
# *args	    Extra positional arguments	   Tuple	     Flexible number of unnamed inputs
# **kwargs	Extra keyword arguments	     Dictionary	       Flexible named inputs

# %%
num=[1,2,3,4,5,6,7,8,9]
greater_than_five=list(lambda num:num>5)
print(greater_than_five)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 num=[1,2,3,4,5,6,7,8,9]
# ----> 2 greater_than_five=list(lambda num:num>5)
#       3 print(greater_than_five)
#
# TypeError: 'function' object is not iterable

# %%
siri=[1,2,3,4,5]
squ=lamda siri:siri*2


##even1=lambda num:num%2==0
##even1(12)
# Out:
#   Cell In[30], line 2
#     squ=lamda siri:siri*2
#               ^
# SyntaxError: invalid syntax
